# %%
import sys
sys.path.append('../SRC')
from data_loader import load_clean_data

df = load_clean_data()

# %%
from extract_names import extract_names, extract_director

df  ['genres'] = df['genres'].apply(extract_names, key='name')
df ['crew'] = df['crew'].apply(extract_director)

# %%
df ['production_companies'] = df['production_companies'].apply(extract_names, key='name')

# %%
df ['keywords'] = df['keywords'].apply(extract_names, key='name')

# %%
from data_preprocessing import convert_to_clean_text, convert_list_to_string

convert_list_to_string(df, ['genres', 'keywords', 'production_companies','crew'])
# Out:
#          budget                                    genres  \
# 0     237000000  Action Adventure Fantasy Science Fiction
# 1     300000000                  Adventure Fantasy Action
# 2     245000000                    Action Adventure Crime
# 3     250000000               Action Crime Drama Thriller
# 4     260000000          Action Adventure Science Fiction
# ...         ...                                       ...
# 4804     220000                     Action Crime Thriller
# 4805       9000                            Comedy Romance
# 4806          0             Comedy Drama Romance TV Movie
# 4807          0
# 4808          0                               Documentary
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# 1          http://disney.go.com/disneypictures/pirates/     285
# 2           http://www.sonypictures.com/movies/spectre/  206647
# ...

# %%
cols = ['genres', 'keywords', 'production_companies', 'crew', 'tagline', 'overview']
df[cols] = df[cols].fillna('')
convert_to_clean_text(df, cols)
# Out:
#          budget                                    genres  \
# 0     237000000  action adventure fantasy science fiction
# 1     300000000                  adventure fantasy action
# 2     245000000                    action adventure crime
# 3     250000000               action crime drama thriller
# 4     260000000          action adventure science fiction
# ...         ...                                       ...
# 4804     220000                     action crime thriller
# 4805       9000                            comedy romance
# 4806          0             comedy drama romance tv movie
# 4807          0
# 4808          0                               documentary
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# 1          http://disney.go.com/disneypictures/pirates/     285
# 2           http://www.sonypictures.com/movies/spectre/  206647
# ...

# %%
df.head()
# Out:
#       budget                                    genres  \
# 0  237000000  Action Adventure Fantasy Science Fiction
# 1  300000000                  Adventure Fantasy Action
# 2  245000000                    Action Adventure Crime
# 3  250000000               Action Crime Drama Thriller
# 4  260000000          Action Adventure Science Fiction
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  culture clash future space war space colony so...                en
# 1  ocean drug abuse exotic island east india trad...                en
# 2  spy based on novel secret agent sequel mi6 bri...                en
# ...

# %%
df.to_csv('../Data/processed/preprocessed_data.csv', index=False)
